# %%
# !pip install gym[box2d]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (2.2.1)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (1.22.4)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (0.0.8)
# Collecting pygame==2.1.0
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 45.8 MB/s eta 0:00:00
# Collecting box2d-py==2.3.5
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting swig==4.*
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.1 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for box2d-py (setup.py) ... error
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# Installing collected packages: swig, box2d-py, pygame
#   Running setup.py install for box2d-py ... done
#   DEPRECATION: box2d-py was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. pip 23.1 will enforce this behaviour change. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.3.0
#     Uninstalling pygame-2.3.0:
#       Successfully uninstalled pygame-2.3.0
# Successfully installed box2d-py-2.3.5 pygame-2.1.0 swig-4.1.1

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import os


class ReplayBuffer:
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape))
        self.new_state_memory = np.zeros((self.mem_size, *input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.terminal_memory[index] = done
        self.reward_memory[index] = reward
        self.action_memory[index] = action

        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        states_ = self.new_state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        dones = self.terminal_memory[batch]

        return states, actions, rewards, states_, dones


class CriticNetwork(keras.Model):
    def __init__(self, fc1_dims, fc2_dims, name, chkpt_dir='tmp/td3'):
        super(CriticNetwork, self).__init__()
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.model_name = name
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_td3')

        self.fc1 = Dense(self.fc1_dims, activation='relu')
        self.fc2 = Dense(self.fc2_dims, activation='relu')
        self.q = Dense(1, activation=None)

    def call(self, state, action):
        q1_action_value = self.fc1(tf.concat([state, action], axis=1))
        q1_action_value = self.fc2(q1_action_value)

        q = self.q(q1_action_value)

        return q


class ActorNetwork(keras.Model):
    def __init__(self, fc1_dims, fc2_dims, n_actions, name,
                 chkpt_dir='tmp/td3'):
        super(ActorNetwork, self).__init__()
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.model_name = name
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name+'_td3')

        self.fc1 = Dense(self.fc1_dims, activation='relu')
        self.fc2 = Dense(self.fc2_dims, activation='relu')
        self.mu = Dense(self.n_actions, activation='tanh')

    def call(self, state):
        prob = self.fc1(state)
        prob = self.fc2(prob)

        mu = self.mu(prob)

        return mu


class Agent:
    def __init__(self, alpha, beta, input_dims, tau, env,
                 gamma=0.99, update_actor_interval=2, warmup=1000,
                 n_actions=2, max_size=1000000, layer1_size=400,
                 layer2_size=300, batch_size=100, noise=0.1):
        self.gamma = gamma
        self.tau = tau
        self.max_action = env.action_space.high[0]
        self.min_action = env.action_space.low[0]
        self.memory = ReplayBuffer(max_size, input_dims, n_actions)
        self.batch_size = batch_size
        self.learn_step_cntr = 0
        self.time_step = 0
        self.warmup = warmup
        self.n_actions = n_actions
        self.update_actor_iter = update_actor_interval

        self.actor = ActorNetwork(layer1_size, layer2_size,
                                  n_actions=n_actions, name='actor')

        self.critic_1 = CriticNetwork(layer1_size, layer2_size,
                                      name='critic_1')
        self.critic_2 = CriticNetwork(layer1_size, layer2_size,
                                      name='critic_2')

        self.target_actor = ActorNetwork(layer1_size, layer2_size,
                                         n_actions=n_actions,
                                         name='target_actor')
        self.target_critic_1 = CriticNetwork(layer1_size, layer2_size,
                                             name='target_critic_1')
        self.target_critic_2 = CriticNetwork(layer1_size, layer2_size,
                                             name='target_critic_2')

        self.actor.compile(optimizer=Adam(learning_rate=alpha), loss='mean')
        self.critic_1.compile(optimizer=Adam(learning_rate=beta),
                              loss='mean_squared_error')
        self.critic_2.compile(optimizer=Adam(learning_rate=beta),
                              loss='mean_squared_error')

        self.target_actor.compile(optimizer=Adam(learning_rate=alpha),
                                  loss='mean')
        self.target_critic_1.compile(optimizer=Adam(learning_rate=beta),
                                     loss='mean_squared_error')
        self.target_critic_2.compile(optimizer=Adam(learning_rate=beta),
                                     loss='mean_squared_error')

        self.noise = noise
        self.update_network_parameters(tau=1)

    def choose_action(self, observation):
        if self.time_step < self.warmup:
            mu = np.random.normal(scale=self.noise, size=(self.n_actions,))
        else:
            state = tf.convert_to_tensor([observation], dtype=tf.float32)
            # returns a batch size of 1, want a scalar array
            mu = self.actor(state)[0]
        mu_prime = mu + np.random.normal(scale=self.noise)

        mu_prime = tf.clip_by_value(mu_prime, self.min_action, self.max_action)
        self.time_step += 1

        return mu_prime

    def remember(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return

        states, actions, rewards, new_states, dones = \
            self.memory.sample_buffer(self.batch_size)

        states = tf.convert_to_tensor(states, dtype=tf.float32)
        actions = tf.convert_to_tensor(actions, dtype=tf.float32)
        rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
        states_ = tf.convert_to_tensor(new_states, dtype=tf.float32)

        with tf.GradientTape(persistent=True) as tape:
            target_actions = self.target_actor(states_)
            target_actions = target_actions + \
                tf.clip_by_value(np.random.normal(scale=0.2), -0.5, 0.5)

            target_actions = tf.clip_by_value(target_actions, self.min_action,
                                              self.max_action)

            q1_ = self.target_critic_1(states_, target_actions)
            q2_ = self.target_critic_2(states_, target_actions)

            q1 = tf.squeeze(self.critic_1(states, actions), 1)
            q2 = tf.squeeze(self.critic_2(states, actions), 1)

            # shape is [batch_size, 1], want to collapse to [batch_size]
            q1_ = tf.squeeze(q1_, 1)
            q2_ = tf.squeeze(q2_, 1)

            critic_value_ = tf.math.minimum(q1_, q2_)
            # in tf2 only integer scalar arrays can be used as indices
            # and eager exection doesn't support assignment, so we can't do
            # q1_[dones] = 0.0
            target = rewards + self.gamma*critic_value_*(1-dones)
            critic_1_loss = keras.losses.MSE(target, q1)
            critic_2_loss = keras.losses.MSE(target, q2)

        critic_1_gradient = tape.gradient(critic_1_loss,
                                          self.critic_1.trainable_variables)
        critic_2_gradient = tape.gradient(critic_2_loss,
                                          self.critic_2.trainable_variables)

        self.critic_1.optimizer.apply_gradients(
                   zip(critic_1_gradient, self.critic_1.trainable_variables))
        self.critic_2.optimizer.apply_gradients(
                   zip(critic_2_gradient, self.critic_2.trainable_variables))

        self.learn_step_cntr += 1

        if self.learn_step_cntr % self.update_actor_iter != 0:
            return

        with tf.GradientTape() as tape:
            new_actions = self.actor(states)
            critic_1_value = self.critic_1(states, new_actions)
            actor_loss = -tf.math.reduce_mean(critic_1_value)

        actor_gradient = tape.gradient(actor_loss,
                                       self.actor.trainable_variables)
        self.actor.optimizer.apply_gradients(
                        zip(actor_gradient, self.actor.trainable_variables))

        self.update_network_parameters()

    def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        weights = []
        targets = self.target_actor.weights
        for i, weight in enumerate(self.actor.weights):
            weights.append(weight * tau + targets[i]*(1-tau))

        self.target_actor.set_weights(weights)

        weights = []
        targets = self.target_critic_1.weights
        for i, weight in enumerate(self.critic_1.weights):
            weights.append(weight * tau + targets[i]*(1-tau))

        self.target_critic_1.set_weights(weights)

        weights = []
        targets = self.target_critic_2.weights
        for i, weight in enumerate(self.critic_2.weights):
            weights.append(weight * tau + targets[i]*(1-tau))

        self.target_critic_2.set_weights(weights)

    def save_models(self):
        print('... saving models ...')
        self.actor.save_weights(self.actor.checkpoint_file)
        self.critic_1.save_weights(self.critic_1.checkpoint_file)
        self.critic_2.save_weights(self.critic_2.checkpoint_file)
        self.target_actor.save_weights(self.target_actor.checkpoint_file)
        self.target_critic_1.save_weights(self.target_critic_1.checkpoint_file)
        self.target_critic_2.save_weights(self.target_critic_2.checkpoint_file)

    def load_models(self):
        print('... loading models ...')
        self.actor.load_weights(self.actor.checkpoint_file)
        self.critic_1.load_weights(self.critic_1.checkpoint_file)
        self.critic_2.load_weights(self.critic_2.checkpoint_file)
        self.target_actor.load_weights(self.target_actor.checkpoint_file)
        self.target_critic_1.load_weights(self.target_critic_1.checkpoint_file)
        self.target_critic_2.load_weights(self.target_critic_2.checkpoint_file)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curve(x, scores, figure_file):
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i-100):(i+1)])
    plt.plot(x, running_avg)
    plt.title('Running average of previous 100 scores')
    plt.savefig(figure_file)

# %%
import gym
import numpy as np
# from td3_tf2 import Agent
# from utils import plot_learning_curve

if __name__ == '__main__':
    env = gym.make('LunarLanderContinuous-v2')
    #env = gym.make('Pendulum-v0')
    # env = gym.make('BipedalWalker-v2')
    agent = Agent(alpha=0.001, beta=0.001,
            input_dims=env.observation_space.shape, tau=0.005,
            env=env, batch_size=100, layer1_size=400, layer2_size=300,
            n_actions=env.action_space.shape[0])
    n_games = 1000
    filename = 'TD3_Lunar_Lander' + 'games.png'

    best_score = env.reward_range[0]
    score_history = []

    #agent.load_models()

    for i in range(n_games):
        observation = env.reset()
        done = False
        score = 0
        while not done:
            action = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            agent.remember(observation, action, reward, observation_, done)
            agent.learn()
            score += reward
            observation = observation_
        score_history.append(score)
        avg_score = np.mean(score_history[-100:])

        if avg_score > best_score:
            best_score = avg_score
            agent.save_models()

        print('episode ', i, 'score %.1f' % score,
                'average score %.1f' % avg_score)

    x = [i+1 for i in range(n_games)]
    plot_learning_curve(x, score_history, filename)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# <ipython-input-2-3eed4a9c6026>:17: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool
# episode  168 score -128.9 average score -153.0
# episode  169 score -112.1 average score -151.3
# episode  170 score 2.6 average score -149.2
# episode  171 score -112.8 average score -146.8
# episode  172 score 44.3 average score -143.2
# episode  173 score -160.1 average score -142.6
# episode  174 score -143.3 average score -141.5
# episode  175 score -204.2 average score -142.0
# episode  176 score -218.8 average score -142.7
# episode  177 score -77.6 average score -141.8
# episode  178 score -145.3 average score -141.0
# episode  179 score -110.1 average score -140.3
# episode  180 score -58.1 average score -135.6
# episode  181 score -172.3 average score -132.4
# episode  182 score -313.6 average score -134.2
# episode  183 score -192.7 average score -132.2
# episode  184 score -93.6 average score -130.0
# episode  185 score -91.1 average score -129.8
# episode  186 score -142.3 average score -127.9
# episode  187 score -83.8 average score -127.6
# ... saving models ...
# episode  188 score -248.8 average score -127.2
# episode  189 score -143.6 average score -127.2
# ... saving models ...
# episode  190 score -155.3 average score -125.1
# ... saving models ...
# episode  191 score -99.9 average score -123.4
# ... saving models ...
# episode  192 score -142.7 average score -122.1
# ... saving models ...
# episode  193 score -12.4 average score -120.6
# ... saving models ...
# episode  194 score -35.1 average score -120.1
# ... saving models ...
# episode  195 score -46.2 average score -119.8
# ... saving models ...
# episode  196 score -110.9 average score -119.8
# ... saving models ...
# episode  197 score -41.1 average score -119.2
# ... saving models ...
# episode  198 score -90.9 average score -116.4
# episode  199 score -298.4 average score -118.7
# episode  200 score -355.0 average score -121.4
# episode  201 score -109.0 average score -117.8
# episode  202 score -119.6 average score -117.7
# episode  203 score -188.7 average score -118.7
# episode  204 score -102.3 average score -118.6
# episode  205 score -432.7 average score -122.3
# episode  206 score -131.3 average score -121.9
# episode  207 score -169.6 average score -122.7
# episode  208 score -143.9 average score -123.1
# episode  209 score -203.0 average score -124.2
# episode  210 score -294.8 average score -126.0
# episode  211 score -211.6 average score -126.2
# episode  212 score -260.4 average score -127.7
# episode  213 score -180.4 average score -128.4
# episode  214 score -86.7 average score -128.2
# episode  215 score -110.0 average score -128.1
# episode  216 score -158.3 average score -128.6
# episode  217 score -204.2 average score -130.3
# episode  218 score -219.6 average score -131.4
# episode  219 score -28.8 average score -130.8
# episode  220 score -134.7 average score -128.2
# episode  221 score -153.6 average score -128.2
# episode  222 score -168.4 average score -126.4
# episode  223 score -148.3 average score -126.1
# episode  224 score -72.1 average score -126.1
# episode  225 score -119.5 average score -126.5
# episode  226 score -59.8 average score -126.7
# episode  227 score -165.8 average score -127.3
# episode  228 score -111.1 average score -127.4
# episode  229 score -192.1 average score -128.4
# episode  230 score -202.6 average score -129.5
# episode  231 score -176.3 average score -130.0
# episode  232 score -363.2 average score -132.5
# episode  233 score -134.3 average score -132.6
# episode  234 score -194.3 average score -133.7
# episode  235 score -275.2 average score -135.9
# episode  236 score -95.1 average score -131.7
# episode  237 score -91.0 average score -132.1
# episode  238 score -84.4 average score -131.8
# episode  239 score -117.9 average score -135.7
# episode  240 score -313.4 average score -137.9
# episode  241 score -59.8 average score -137.1
# episode  242 score 96.5 average score -135.4
# episode  243 score -98.6 average score -135.8
# episode  244 score -407.2 average score -138.8
# episode  326 score -175.0 average score -121.6
# episode  327 score -156.1 average score -121.5
# episode  328 score -462.9 average score -125.0
# episode  329 score -85.1 average score -124.0
# episode  330 score -169.5 average score -123.6
# episode  331 score -78.6 average score -122.6
# episode  332 score -34.3 average score -119.4
# episode  333 score -6.9 average score -118.1
# episode  334 score -51.7 average score -116.7
# ... saving models ...
# episode  335 score -41.8 average score -114.3
# episode  336 score -198.8 average score -115.4
# episode  337 score -491.4 average score -119.4
# episode  338 score -42.4 average score -118.9
# episode  339 score -96.4 average score -118.7
# episode  340 score -208.8 average score -117.7
# episode  341 score 239.6 average score -114.7
# episode  342 score -175.3 average score -117.4
# episode  343 score -300.2 average score -119.4
# episode  344 score 23.7 average score -115.1
# episode  345 score -286.0 average score -117.4
# episode  346 score -119.9 average score -115.8
# episode  347 score -108.6 average score -116.0
# ... saving models ...
# episode  348 score 72.9 average score -111.9
# episode  349 score -232.9 average score -113.9
# episode  350 score -267.1 average score -116.0
# episode  351 score 18.8 average score -114.5
# episode  352 score -82.7 average score -114.3
# ... saving models ...
# episode  353 score 239.2 average score -110.7
# episode  354 score -263.7 average score -111.4
# ... saving models ...
# episode  355 score -35.9 average score -110.0
# ... saving models ...
# episode  356 score 156.9 average score -107.7
# ... saving models ...
# episode  357 score -8.8 average score -106.3
# ... saving models ...
# episode  358 score -214.1 average score -105.7
# ... saving models ...
# episode  359 score -79.6 average score -104.9
# ... saving models ...
# episode  360 score 199.5 average score -101.1
# ... saving models ...
# episode  361 score 163.4 average score -98.0
# episode  362 score -416.2 average score -101.2
# episode  363 score -355.0 average score -103.3
# episode  364 score 67.7 average score -100.9
# episode  365 score -160.6 average score -101.6
# episode  366 score -286.5 average score -104.4
# episode  367 score -157.9 average score -105.4
# episode  368 score -282.8 average score -104.6
# episode  369 score 202.9 average score -99.3
# episode  370 score -80.1 average score -99.2
# episode  371 score -31.5 average score -100.4
# episode  372 score -279.6 average score -101.5
# episode  373 score -270.5 average score -103.4
# episode  374 score 85.6 average score -102.7
# episode  375 score -306.1 average score -105.2
# episode  376 score 10.4 average score -104.8
# episode  377 score 40.3 average score -103.2
# episode  378 score -169.8 average score -103.9
# episode  379 score -61.5 average score -104.2
# episode  380 score -51.3 average score -101.8
# episode  381 score -48.2 average score -101.0
# episode  382 score -130.5 average score -102.2
# episode  383 score -76.4 average score -102.5
# episode  384 score -140.6 average score -102.4
# episode  385 score -17.1 average score -101.6
# episode  386 score -67.0 average score -100.8
# episode  387 score -84.9 average score -101.9
# episode  388 score -31.6 average score -102.3
# episode  389 score -52.1 average score -102.3
# episode  390 score 12.6 average score -102.0
# episode  391 score -267.9 average score -100.0
# episode  392 score -60.7 average score -100.8
# episode  393 score -92.6 average score -100.3
# episode  394 score -195.7 average score -98.8
# episode  395 score -199.3 average score -100.6
# episode  396 score -149.9 average score -102.1
# episode  397 score -186.7 average score -101.1
# episode  398 score -34.5 average score -103.2
# episode  399 score -175.8 average score -104.5
# episode  400 score 136.0 average score -102.1
# episode  401 score -8.3 average score -101.8
# episode  402 score -79.3 average score -100.3
# episode  403 score -35.0 average score -99.6
# episode  404 score -41.1 average score -99.7
# episode  405 score -29.1 average score -99.1
# episode  406 score -18.9 average score -98.6
# ... saving models ...
# episode  407 score -8.2 average score -96.7
# episode  408 score -66.7 average score -97.4
# episode  409 score -59.5 average score -97.7
# episode  410 score -56.7 average score -97.6
# episode  411 score -56.2 average score -97.8
# episode  412 score -27.0 average score -97.4
# episode  413 score -67.8 average score -97.4
# episode  414 score -69.2 average score -97.5
# episode  415 score -19.0 average score -97.2
# ... saving models ...
# episode  416 score -11.6 average score -96.2
# episode  417 score -52.4 average score -96.6
# ... saving models ...
# episode  418 score -36.8 average score -95.0
# ... saving models ...
# episode  419 score -54.3 average score -93.9
# episode  420 score -341.1 average score -96.2
# episode  421 score -21.8 average score -95.2
# ... saving models ...
# episode  422 score -41.9 average score -93.8
# ... saving models ...
# episode  423 score -49.1 average score -93.0
# ... saving models ...
# episode  424 score -62.1 average score -92.3
# ... saving models ...
# episode  425 score -38.7 average score -90.8
# ... saving models ...
# episode  426 score -24.2 average score -89.3
# ... saving models ...
# episode  427 score -73.3 average score -88.4
# ... saving models ...
# episode  428 score -46.6 average score -84.3
# ... saving models ...
# episode  429 score -64.6 average score -84.1
# ... saving models ...
# episode  430 score -48.5 average score -82.9
# ... saving models ...
# episode  431 score -71.4 average score -82.8
# episode  432 score -45.8 average score -82.9
# episode  433 score -209.0 average score -84.9
# episode  434 score -94.7 average score -85.4
# episode  435 score -101.9 average score -86.0
# episode  436 score -225.4 average score -86.2
# ... saving models ...
# episode  437 score 21.9 average score -81.1
# ... saving models ...
# episode  438 score 7.6 average score -80.6
# ... saving models ...
# episode  439 score 7.0 average score -79.6
# ... saving models ...
# episode  440 score -102.6 average score -78.5
# episode  441 score -74.8 average score -81.6
# episode  442 score -127.8 average score -81.2
# episode  443 score -96.0 average score -79.1
# episode  444 score -88.8 average score -80.2
# ... saving models ...
# episode  445 score -5.1 average score -77.4
# ... saving models ...
# episode  446 score -54.3 average score -76.8
# episode  447 score -215.6 average score -77.9
# episode  448 score -69.2 average score -79.3
# episode  449 score -64.1 average score -77.6
# ... saving models ...
# episode  450 score -51.0 average score -75.4
# episode  451 score -62.4 average score -76.2
# episode  452 score -111.6 average score -76.5
# episode  453 score 186.9 average score -77.0
# ... saving models ...
# episode  454 score 163.2 average score -72.8
# ... saving models ...
# episode  455 score 222.9 average score -70.2
# episode  456 score -37.5 average score -72.1
# episode  457 score 141.6 average score -70.6
# ... saving models ...
# episode  458 score 245.7 average score -66.0
# ... saving models ...
# episode  459 score 173.6 average score -63.5
# episode  460 score -19.8 average score -65.7
# episode  461 score 182.4 average score -65.5
# ... saving models ...
# episode  462 score -43.9 average score -61.8
# ... saving models ...
# episode  463 score -18.8 average score -58.4
# ... saving models ...
# episode  464 score 158.2 average score -57.5
# ... saving models ...
# episode  465 score 89.6 average score -55.0
# ... saving models ...
# episode  466 score 142.6 average score -50.7
# ... saving models ...
# episode  467 score 9.9 average score -49.0
# ... saving models ...
# episode  468 score 73.1 average score -45.5
# episode  469 score -25.8 average score -47.8
# episode  470 score -9.0 average score -47.1
# episode  471 score 2.4 average score -46.7
# ... saving models ...
# episode  472 score -48.7 average score -44.4
# ... saving models ...
# episode  473 score -51.8 average score -42.2
# episode  474 score 0.8 average score -43.1
# ... saving models ...
# episode  475 score 187.7 average score -38.1
# episode  476 score -20.2 average score -38.4
# episode  477 score -34.4 average score -39.2
# ... saving models ...
# episode  478 score -44.6 average score -37.9
# ... saving models ...
# episode  479 score -52.8 average score -37.8
# ... saving models ...
# episode  480 score 18.7 average score -37.2
# ... saving models ...
# episode  481 score 222.2 average score -34.4
# ... saving models ...
# episode  482 score -59.2 average score -33.7
# ... saving models ...
# episode  483 score -26.9 average score -33.2
# ... saving models ...
# episode  484 score 163.5 average score -30.2
# ... saving models ...
# episode  485 score 214.9 average score -27.9
# ... saving models ...
# episode  486 score 171.5 average score -25.5
# ... saving models ...
# episode  487 score -23.0 average score -24.9
# episode  488 score -72.8 average score -25.3
# episode  489 score -14.8 average score -24.9
# episode  490 score -59.0 average score -25.6
# ... saving models ...
# episode  491 score -50.0 average score -23.4
# ... saving models ...
# episode  492 score -6.0 average score -22.9
# ... saving models ...
# episode  493 score -37.7 average score -22.4
# ... saving models ...
# episode  494 score -21.7 average score -20.6
# ... saving models ...
# episode  495 score -27.9 average score -18.9
# ... saving models ...
# episode  496 score -34.8 average score -17.7
# ... saving models ...
# episode  497 score 9.2 average score -15.8
# ... saving models ...
# episode  498 score 15.9 average score -15.3
# ... saving models ...
# episode  499 score -26.6 average score -13.8
# episode  500 score -41.2 average score -15.6
# episode  501 score 6.1 average score -15.4
# episode  502 score -34.2 average score -15.0
# episode  503 score -10.0 average score -14.7
# episode  504 score -1.3 average score -14.3
# ... saving models ...
# episode  505 score 165.5 average score -12.4
# ... saving models ...
# episode  506 score -14.8 average score -12.3
# ... saving models ...
# episode  507 score -5.4 average score -12.3
# ... saving models ...
# episode  508 score -16.6 average score -11.8
# ... saving models ...
# episode  509 score 283.1 average score -8.4
# episode  510 score -62.3 average score -8.4
# ... saving models ...
# episode  511 score -38.2 average score -8.3
# episode  512 score -47.1 average score -8.5
# ... saving models ...
# episode  513 score -32.3 average score -8.1
# episode  514 score -176.2 average score -9.2
# episode  515 score -36.1 average score -9.3
# episode  516 score -37.6 average score -9.6
# episode  517 score 71.6 average score -8.4
# episode  518 score -163.6 average score -9.6
# episode  519 score -46.5 average score -9.6
# ... saving models ...
# episode  520 score -26.9 average score -6.4
# ... saving models ...
# episode  521 score -21.5 average score -6.4
# episode  522 score -49.1 average score -6.5
# ... saving models ...
# episode  523 score -27.4 average score -6.3
# ... saving models ...
# episode  524 score 199.7 average score -3.6
# episode  525 score -39.9 average score -3.7
# episode  526 score -49.0 average score -3.9
# ... saving models ...
# episode  527 score -46.1 average score -3.6
# ... saving models ...
# episode  528 score -27.5 average score -3.4
# ... saving models ...
# episode  529 score -48.6 average score -3.3
# ... saving models ...
# episode  530 score -13.9 average score -2.9
# ... saving models ...
# episode  531 score 7.2 average score -2.2
# ... saving models ...
# episode  532 score -32.4 average score -2.0
# ... saving models ...
# episode  533 score 48.8 average score 0.6
# ... saving models ...
# episode  534 score 5.1 average score 1.6
# ... saving models ...
# episode  535 score 79.6 average score 3.4
# ... saving models ...
# episode  536 score -15.6 average score 5.5
# episode  537 score -52.6 average score 4.7
# episode  538 score -116.9 average score 3.5
# episode  539 score -14.2 average score 3.3
# ... saving models ...
# episode  540 score 155.5 average score 5.9
# ... saving models ...
# episode  541 score -18.7 average score 6.4
# ... saving models ...
# episode  542 score -26.9 average score 7.4
# ... saving models ...
# episode  543 score 45.5 average score 8.8
# ... saving models ...
# episode  544 score -3.5 average score 9.7
# episode  545 score -13.4 average score 9.6
# ... saving models ...
# episode  546 score 233.6 average score 12.5
# ... saving models ...
# episode  547 score -28.3 average score 14.4
# ... saving models ...
# episode  548 score 211.3 average score 17.2
# episode  549 score -72.4 average score 17.1
# ... saving models ...
# episode  550 score -27.2 average score 17.3
# ... saving models ...
# episode  551 score 242.6 average score 20.4
# ... saving models ...
# episode  552 score -32.3 average score 21.2
# episode  553 score -26.8 average score 19.0
# episode  554 score 165.0 average score 19.0
# episode  555 score 255.2 average score 19.4
# episode  556 score 26.9 average score 20.0
# episode  557 score -1.3 average score 18.6
# episode  558 score 169.7 average score 17.8
# episode  559 score -12.6 average score 16.0
# episode  560 score 187.6 average score 18.0
# episode  561 score 34.2 average score 16.6
# episode  562 score 182.4 average score 18.8
# episode  563 score 13.1 average score 19.1
# episode  564 score 37.2 average score 17.9
# episode  565 score 283.1 average score 19.9
# episode  566 score -42.9 average score 18.0
# episode  567 score -67.4 average score 17.2
# episode  568 score 224.9 average score 18.7
# episode  569 score 115.7 average score 20.2
# episode  570 score 26.1 average score 20.5
# episode  571 score 8.4 average score 20.6
# ... saving models ...
# episode  572 score 205.0 average score 23.1
# ... saving models ...
# episode  573 score -41.7 average score 23.2
# episode  574 score -199.7 average score 21.2
# episode  575 score 155.2 average score 20.9
# episode  576 score -44.3 average score 20.6
# episode  577 score -26.3 average score 20.7
# ... saving models ...
# episode  578 score 216.5 average score 23.3
# ... saving models ...
# episode  579 score 23.6 average score 24.1
# ... saving models ...
# episode  580 score 24.0 average score 24.2
# episode  581 score -0.4 average score 21.9
# episode  582 score -210.3 average score 20.4
# episode  583 score -84.6 average score 19.8
# episode  584 score 142.1 average score 19.6
# episode  585 score 166.1 average score 19.1
# episode  586 score -111.1 average score 16.3
# episode  587 score -106.3 average score 15.5
# episode  588 score 0.4 average score 16.2
# episode  589 score -27.6 average score 16.1
# episode  590 score -14.6 average score 16.5
# episode  591 score -102.7 average score 16.0
# episode  592 score 175.0 average score 17.8
# episode  593 score -10.0 average score 18.1
# episode  594 score 140.4 average score 19.7
# episode  595 score -50.6 average score 19.5
# episode  596 score -15.4 average score 19.7
# episode  597 score 175.2 average score 21.3
# episode  598 score 150.3 average score 22.7
# episode  599 score -21.5 average score 22.7
# episode  600 score 11.0 average score 23.3
# ... saving models ...
# episode  601 score 178.1 average score 25.0
# ... saving models ...
# episode  602 score 211.2 average score 27.4
# ... saving models ...
# episode  603 score 186.6 average score 29.4
# ... saving models ...
# episode  604 score 99.8 average score 30.4
# ... saving models ...
# episode  605 score 172.6 average score 30.5
# ... saving models ...
# episode  606 score 235.7 average score 33.0
# episode  607 score -13.5 average score 32.9
# ... saving models ...
# episode  608 score 202.2 average score 35.1
# episode  609 score 36.7 average score 32.6
# ... saving models ...
# episode  610 score 213.7 average score 35.4
# ... saving models ...
# episode  611 score 171.0 average score 37.5
# ... saving models ...
# episode  612 score 182.8 average score 39.8
# ... saving models ...
# episode  613 score 205.2 average score 42.1
# ... saving models ...
# episode  614 score 198.5 average score 45.9
# ... saving models ...
# episode  615 score -16.9 average score 46.1
# ... saving models ...
# episode  616 score 155.4 average score 48.0
# episode  617 score -49.5 average score 46.8
# ... saving models ...
# episode  618 score -11.5 average score 48.3
# ... saving models ...
# episode  619 score 156.7 average score 50.4
# ... saving models ...
# episode  620 score 147.1 average score 52.1
# episode  621 score -25.8 average score 52.1
# ... saving models ...
# episode  622 score 116.3 average score 53.7
# ... saving models ...
# episode  623 score -23.7 average score 53.7
# episode  624 score 124.7 average score 53.0
# episode  625 score -33.0 average score 53.1
# ... saving models ...
# episode  626 score 239.5 average score 56.0
# ... saving models ...
# episode  627 score 226.3 average score 58.7
# ... saving models ...
# episode  628 score 125.3 average score 60.2
# ... saving models ...
# episode  629 score -31.6 average score 60.4
# ... saving models ...
# episode  630 score 166.8 average score 62.2
# ... saving models ...
# episode  631 score 65.4 average score 62.8
# ... saving models ...
# episode  632 score 93.4 average score 64.0
# ... saving models ...
# episode  633 score 160.4 average score 65.1
# ... saving models ...
# episode  634 score 145.2 average score 66.5
# ... saving models ...
# episode  635 score 166.7 average score 67.4
# ... saving models ...
# episode  636 score 291.5 average score 70.5
# ... saving models ...
# episode  637 score 171.9 average score 72.7
# ... saving models ...
# episode  638 score -29.6 average score 73.6
# episode  639 score -190.4 average score 71.8
# episode  640 score 200.7 average score 72.3
# ... saving models ...
# episode  641 score 212.5 average score 74.6
# ... saving models ...
# episode  642 score 199.2 average score 76.9
# ... saving models ...
# episode  643 score 212.2 average score 78.5
# ... saving models ...
# episode  644 score 273.4 average score 81.3
# episode  645 score -53.1 average score 80.9
# episode  646 score 258.3 average score 81.1
# ... saving models ...
# episode  647 score 294.2 average score 84.4
# episode  648 score 179.7 average score 84.1
# ... saving models ...
# episode  649 score 266.6 average score 87.4
# episode  650 score -302.7 average score 84.7
# episode  651 score 244.4 average score 84.7
# ... saving models ...
# episode  652 score 267.5 average score 87.7
# episode  653 score -209.5 average score 85.9
# episode  654 score -162.6 average score 82.6
# episode  655 score 233.1 average score 82.4
# episode  656 score 213.9 average score 84.3
# episode  657 score 233.3 average score 86.6
# episode  658 score 194.4 average score 86.8
# ... saving models ...
# episode  659 score 171.5 average score 88.7
# episode  660 score 169.1 average score 88.5
# ... saving models ...
# episode  661 score 210.6 average score 90.3
# ... saving models ...
# episode  662 score 197.5 average score 90.4
# ... saving models ...
# episode  663 score 239.3 average score 92.7
# ... saving models ...
# episode  664 score 168.0 average score 94.0
# episode  665 score 121.6 average score 92.4
# ... saving models ...
# episode  666 score 277.9 average score 95.6
# ... saving models ...
# episode  667 score 224.8 average score 98.5
# episode  668 score 203.7 average score 98.3
# episode  669 score -15.2 average score 97.0
# ... saving models ...
# episode  670 score 233.5 average score 99.1
# ... saving models ...
# episode  671 score 17.1 average score 99.1
# episode  672 score 184.4 average score 98.9
# ... saving models ...
# episode  673 score 191.5 average score 101.3
# ... saving models ...
# episode  674 score 245.3 average score 105.7
# episode  675 score 130.4 average score 105.5
# ... saving models ...
# episode  676 score 272.8 average score 108.6
# ... saving models ...
# episode  677 score 220.1 average score 111.1
# ... saving models ...
# episode  678 score 263.0 average score 111.6
# ... saving models ...
# episode  679 score 84.7 average score 112.2
# ... saving models ...
# episode  680 score 232.5 average score 114.3
# episode  681 score -17.9 average score 114.1
# ... saving models ...
# episode  682 score 113.7 average score 117.3
# ... saving models ...
# episode  683 score 275.8 average score 120.9
# ... saving models ...
# episode  684 score 238.8 average score 121.9
# ... saving models ...
# episode  685 score 273.6 average score 123.0
# ... saving models ...
# episode  686 score -44.3 average score 123.6
# ... saving models ...
# episode  687 score -46.9 average score 124.2
# episode  688 score -26.7 average score 124.0
# episode  689 score -161.2 average score 122.6
# ... saving models ...
# episode  690 score 179.8 average score 124.6
# ... saving models ...
# episode  691 score 246.2 average score 128.1
# ... saving models ...
# episode  692 score 268.7 average score 129.0
# ... saving models ...
# episode  693 score 261.1 average score 131.7
# episode  694 score 43.3 average score 130.7
# ... saving models ...
# episode  695 score 278.9 average score 134.0
# ... saving models ...
# episode  696 score 254.9 average score 136.7
# ... saving models ...
# episode  697 score 256.8 average score 137.6
# ... saving models ...
# episode  698 score 165.1 average score 137.7
# ... saving models ...
# episode  699 score -4.9 average score 137.9
# ... saving models ...
# episode  700 score 253.5 average score 140.3
# ... saving models ...
# episode  701 score 269.3 average score 141.2
# ... saving models ...
# episode  702 score 245.5 average score 141.5
# episode  703 score 12.3 average score 139.8
# episode  704 score 249.1 average score 141.3
# episode  705 score 156.0 average score 141.1
# episode  706 score 265.4 average score 141.4
# ... saving models ...
# episode  707 score 276.1 average score 144.3
# ... saving models ...
# episode  708 score 250.5 average score 144.8
# ... saving models ...
# episode  709 score 191.8 average score 146.4
# ... saving models ...
# episode  710 score 218.0 average score 146.4
# ... saving models ...
# episode  711 score 256.0 average score 147.3
# ... saving models ...
# episode  712 score 282.5 average score 148.2
# ... saving models ...
# episode  713 score 220.1 average score 148.4
# ... saving models ...
# episode  714 score 272.3 average score 149.1
# ... saving models ...
# episode  715 score 217.8 average score 151.5
# ... saving models ...
# episode  716 score 266.4 average score 152.6
# ... saving models ...
# episode  717 score 309.5 average score 156.2
# ... saving models ...
# episode  718 score 235.4 average score 158.7
# ... saving models ...
# episode  719 score 276.5 average score 159.8
# ... saving models ...
# episode  720 score 217.4 average score 160.6
# ... saving models ...
# episode  721 score 211.0 average score 162.9
# ... saving models ...
# episode  722 score 284.4 average score 164.6
# ... saving models ...
# episode  723 score 228.6 average score 167.1
# ... saving models ...
# episode  724 score 233.0 average score 168.2
# episode  725 score -83.2 average score 167.7
# ... saving models ...
# episode  726 score 293.2 average score 168.2
# episode  727 score 185.9 average score 167.8
# ... saving models ...
# episode  728 score 245.4 average score 169.0
# ... saving models ...
# episode  729 score 167.4 average score 171.0
# ... saving models ...
# episode  730 score 308.4 average score 172.4
# ... saving models ...
# episode  731 score 297.5 average score 174.8
# ... saving models ...
# episode  732 score 235.4 average score 176.2
# ... saving models ...
# episode  733 score 269.2 average score 177.3
# ... saving models ...
# episode  734 score 234.3 average score 178.2
# ... saving models ...
# episode  735 score 186.1 average score 178.4
# episode  736 score 187.5 average score 177.3
# episode  737 score 268.2 average score 178.3
# ... saving models ...
# episode  738 score 242.7 average score 181.0
# ... saving models ...
# episode  739 score 267.0 average score 185.6
# ... saving models ...
# episode  740 score 250.3 average score 186.1
# ... saving models ...
# episode  741 score 241.0 average score 186.4
# ... saving models ...
# episode  742 score 274.6 average score 187.1
# ... saving models ...
# episode  743 score 220.8 average score 187.2
# episode  744 score -58.0 average score 183.9
# episode  745 score 154.1 average score 186.0
# episode  746 score 233.3 average score 185.7
# episode  747 score -28.0 average score 182.5
# episode  748 score 128.9 average score 182.0
# episode  749 score 241.7 average score 181.7
# ... saving models ...
# episode  750 score 284.9 average score 187.6
# ... saving models ...
# episode  751 score 263.4 average score 187.8
# episode  752 score 236.9 average score 187.5
# ... saving models ...
# episode  753 score -70.5 average score 188.9
# ... saving models ...
# episode  754 score 268.2 average score 193.2
# ... saving models ...
# episode  755 score 252.9 average score 193.4
# episode  756 score 172.8 average score 193.0
# episode  757 score 225.2 average score 192.9
# episode  758 score 162.9 average score 192.6
# episode  759 score 249.9 average score 193.4
# ... saving models ...
# episode  760 score 262.9 average score 194.3
# ... saving models ...
# episode  761 score 285.0 average score 195.0
# episode  762 score 190.5 average score 195.0
# ... saving models ...
# episode  763 score 291.1 average score 195.5
# ... saving models ...
# episode  764 score 247.7 average score 196.3
# ... saving models ...
# episode  765 score 292.4 average score 198.0
# episode  766 score 271.0 average score 197.9
# ... saving models ...
# episode  767 score 279.4 average score 198.5
# episode  768 score -25.7 average score 196.2
# ... saving models ...
# episode  769 score 250.1 average score 198.8
# ... saving models ...
# episode  770 score 280.5 average score 199.3
# ... saving models ...
# episode  771 score 239.2 average score 201.5
# ... saving models ...
# episode  772 score 247.9 average score 202.2
# ... saving models ...
# episode  773 score 242.0 average score 202.7
# ... saving models ...
# episode  774 score 263.4 average score 202.8
# ... saving models ...
# episode  775 score 274.7 average score 204.3
# ... saving models ...
# episode  776 score 275.5 average score 204.3
# ... saving models ...
# episode  777 score 266.1 average score 204.8
# episode  778 score 250.8 average score 204.7
# ... saving models ...
# episode  779 score 267.2 average score 206.5
# episode  780 score -56.5 average score 203.6
# ... saving models ...
# episode  781 score 285.5 average score 206.6
# ... saving models ...
# episode  782 score 239.4 average score 207.9
# ... saving models ...
# episode  783 score 286.5 average score 208.0
# episode  784 score 213.2 average score 207.7
# episode  785 score 264.8 average score 207.6
# ... saving models ...
# episode  786 score 29.6 average score 208.4
# ... saving models ...
# episode  861 score 254.4 average score 221.2
# episode  862 score 291.1 average score 222.2
# episode  863 score 256.8 average score 221.8
# episode  864 score 285.7 average score 222.2
# episode  865 score 302.5 average score 222.3
# episode  866 score 275.5 average score 222.4
# episode  867 score 278.8 average score 222.4
# episode  868 score 271.4 average score 225.3
# episode  869 score 269.6 average score 225.5
# episode  870 score 256.3 average score 225.3
# episode  871 score 271.8 average score 225.6
# episode  872 score 173.2 average score 224.9
# episode  873 score 272.2 average score 225.2
# episode  874 score 293.8 average score 225.5
# episode  875 score 291.0 average score 225.6
# episode  876 score 291.7 average score 225.8
# episode  877 score 251.2 average score 225.7
# episode  878 score 267.4 average score 225.8
# episode  879 score 291.0 average score 226.1
# ... saving models ...
# episode  880 score 271.3 average score 229.3
# episode  881 score 272.4 average score 229.2
# ... saving models ...
# episode  882 score 280.4 average score 229.6
# episode  883 score 255.6 average score 229.3
# ... saving models ...
# episode  884 score 300.2 average score 230.2
# episode  885 score 203.7 average score 229.6
# ... saving models ...
# episode  886 score 273.3 average score 232.0
# ... saving models ...
# episode  887 score 265.9 average score 232.1
# episode  888 score 256.6 average score 231.7
# episode  889 score 259.8 average score 231.8
# ... saving models ...
# episode  890 score 268.8 average score 235.1
# ... saving models ...
# episode  891 score 274.7 average score 235.1
# ... saving models ...
# episode  892 score 265.4 average score 236.4
# episode  893 score 266.5 average score 236.3
# ... saving models ...
# episode  894 score 285.1 average score 237.3
# ... saving models ...
# episode  895 score 307.1 average score 238.6
# episode  896 score 256.9 average score 238.5
# ... saving models ...
# episode  897 score 265.2 average score 238.7
# ... saving models ...
# episode  898 score 268.7 average score 239.7
# ... saving models ...
# episode  899 score 279.8 average score 239.9
# episode  900 score 272.3 average score 239.7
# ... saving models ...
# episode  901 score 295.0 average score 240.0
# episode  902 score 258.9 average score 239.7
# episode  903 score 292.0 average score 239.9
# episode  904 score 256.6 average score 239.5
# ... saving models ...
# episode  905 score 270.2 average score 240.5
# ... saving models ...
# episode  906 score 287.1 average score 240.7
# ... saving models ...
# episode  907 score 280.1 average score 240.9
# ... saving models ...
# episode  908 score 282.9 average score 241.1
# ... saving models ...
# episode  909 score 295.8 average score 241.2
# episode  910 score 277.7 average score 241.1
# ... saving models ...
# episode  911 score 274.0 average score 242.1
# ... saving models ...
# episode  912 score 280.0 average score 242.3
# ... saving models ...
# episode  913 score 249.7 average score 243.1
# ... saving models ...
# episode  914 score 272.8 average score 243.8
# ... saving models ...
# episode  915 score 302.5 average score 244.2
# ... saving models ...
# episode  916 score 288.7 average score 244.3
# episode  917 score 281.8 average score 244.2
# episode  918 score 247.4 average score 243.7
# episode  919 score 276.7 average score 243.7
# ... saving models ...
# episode  920 score 246.7 average score 244.5
# episode  921 score 272.7 average score 244.4
# ... saving models ...
# episode  922 score 275.9 average score 244.6
# episode  923 score 240.5 average score 244.1
# episode  924 score 252.9 average score 243.6
# ... saving models ...
# episode  925 score 287.9 average score 246.7
# episode  926 score 270.0 average score 246.5
# episode  927 score 284.4 average score 246.5
# episode  928 score 240.1 average score 245.8
# episode  929 score 266.9 average score 245.9
